# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score
from catboost import CatBoostRegressor
pd.options.display.max_columns = None
pd.options.display.max_rows = 100
sns.set_style('darkgrid')

# %% [markdown]
# # Read CSV

# %%
data = pd.read_csv('../dataset/train.csv')
test = pd.read_csv('../dataset/test.csv')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Combine 2 train and test dataset

# %%
target = data['SalePrice']
test_ids = test['Id']

train_init = data.drop(['Id', 'SalePrice'], axis=1)
test_init = test.drop('Id', axis=1)

data1 = pd.concat([train_init, test_init], axis=0).reset_index(drop=True)
data1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2914         160       RM         21.0     1936   Pave   NaN      Reg
# 2915         160       RM         21.0     1894   Pave   NaN      Reg
# 2916          20       RL        160.0    20000   Pave   NaN      Reg
# 2917          85       RL         62.0    10441   Pave   NaN      Reg
# 2918          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
data2 = data1.copy()

# %% [markdown]
# ## Ensure Proper Data Types

# %%
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# ## Finding the categorical columns

# %%
pd.DataFrame(data2.loc[:, data2.isna().sum() > 0].columns, columns=['Features'] )
# Out:
#         Features
# 0       MSZoning
# 1    LotFrontage
# 2          Alley
# 3      Utilities
# 4    Exterior1st
# 5    Exterior2nd
# 6     MasVnrType
# 7     MasVnrArea
# 8       BsmtQual
# 9       BsmtCond
# 10  BsmtExposure
# 11  BsmtFinType1
# 12    BsmtFinSF1
# 13  BsmtFinType2
# 14    BsmtFinSF2
# 15     BsmtUnfSF
# 16   TotalBsmtSF
# 17    Electrical
# 18  BsmtFullBath
# 19  BsmtHalfBath
# 20   KitchenQual
# 21    Functional
# 22   FireplaceQu
# 23    GarageType
# 24   GarageYrBlt
# 25  GarageFinish
# 26    GarageCars
# 27    GarageArea
# 28    GarageQual
# 29    GarageCond
# 30        PoolQC
# 31         Fence
# 32   MiscFeature
# 33      SaleType

# %% [markdown]
# ## Finding null attributes

# %%
features_null_prcnt = []
features_drop_list = []
exceed_prcnt = 50
columns = data2.columns
for col in columns:
    prcnt = len(data2[col][data2[col].isna() == True]) / len(data2[col])*100
    if (prcnt > exceed_prcnt):
        features_drop_list.append(col)
    features_null_prcnt.append(prcnt)
Nan_values = pd.DataFrame({'Features' : columns, 'NaN_Percentage': features_null_prcnt}).sort_values(by = 'NaN_Percentage', ascending = False)
Nan_values = Nan_values[Nan_values.NaN_Percentage > 1]
 
plt.figure(figsize=(10,7))
plt.title('Percentage of NaN values in Categorical Features', size = 20)
plt.xlabel("Features with Highest NaN values")
sns.barplot(x = Nan_values.NaN_Percentage, y = Nan_values.Features, orient = 'h', palette = 'rainbow')
plt.show()
print('We can remove features with NaN values that are more than ' + str(exceed_prcnt) + '%.')
# Out:
# We can remove features with NaN values that are more than 50%.

# %%
features_drop_list
# Out:
# ['Alley', 'PoolQC', 'Fence', 'MiscFeature']

# %% [markdown]
# ## Drop the columns - nan values which exceed 50%

# %%
data3 = data2.drop(features_drop_list, axis=1)
data3 = data2.copy()

# %% [markdown]
# ## Fill Categorical Missing Values

# %%
# # Impute using a constant value
# # non_drop
# for column in [
#     'BsmtQual',
#     'BsmtCond',
#     'BsmtExposure',
#     'BsmtFinType1',
#     'BsmtFinType2',
#     'FireplaceQu',
#     'GarageType',
#     'GarageFinish',
#     'GarageQual',
#     'GarageCond',
#     'Alley', 
#     'PoolQC', 
#     'Fence', 
#     'MiscFeature'
# ]:
#     data3[column] = data3[column].fillna("None")

# dropped Version
for column in [
    'BsmtQual',
    'BsmtCond',
    'BsmtExposure',
    'BsmtFinType1',
    'BsmtFinType2',
    'FireplaceQu',
    'GarageType',
    'GarageFinish',
    'GarageQual',
    'GarageCond',
]:
    data3[column] = data3[column].fillna("None")

# Impute using the column mode
for column in [
    'MSZoning',
    'Utilities',
    'Exterior1st',
    'Exterior2nd',
    'MasVnrType',
    'Electrical',
    'KitchenQual',
    'Functional',
    'SaleType'
]:
    data3[column] = data3[column].fillna(data3[column].mode()[0])

# %%
data4 = data3.copy()

# %% [markdown]
# ## Numeric Missing Values

# %% [markdown]
# knn methods

# %%
def knn_impute(df, na_target):
    df = df.copy()
    
    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[: ,numeric_df.isna().sum() == 0].columns
    
    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    
    df.loc[df[na_target].isna() == True, na_target] = y_pred
    
    return df

# %%
# for column in [
#     'LotFrontage',
#     'MasVnrArea',
#     'BsmtFinSF1',
#     'BsmtFinSF2',
#     'BsmtUnfSF',
#     'TotalBsmtSF',
#     'BsmtFullBath',
#     'BsmtHalfBath',
#     'GarageYrBlt',
#     'GarageCars',
#     'GarageArea'
# ]:
#     data4 = knn_impute(data4, column)

# %% [markdown]
# Mean Method

# %%
for column in [
    'LotFrontage',
    'MasVnrArea',
    'BsmtFinSF1',
    'BsmtFinSF2',
    'BsmtUnfSF',
    'TotalBsmtSF',
    'BsmtFullBath',
    'BsmtHalfBath',
    'GarageYrBlt',
    'GarageCars',
    'GarageArea'
]:
    data4[column] = data4[column].fillna(data4[column].mean())

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Print the numerical values

# %%
for attribute in data4:
    if data[attribute].dtypes == 'int64' or data[attribute].dtypes == 'float64':
        print(attribute + ": " +str(data[attribute].dtypes))
# Out:
# MSSubClass: int64
# LotFrontage: float64
# LotArea: int64
# OverallQual: int64
# OverallCond: int64
# YearBuilt: int64
# YearRemodAdd: int64
# MasVnrArea: float64
# BsmtFinSF1: int64
# BsmtFinSF2: int64
# BsmtUnfSF: int64
# TotalBsmtSF: int64
# 1stFlrSF: int64
# 2ndFlrSF: int64
# LowQualFinSF: int64
# GrLivArea: int64
# BsmtFullBath: int64
# BsmtHalfBath: int64
# FullBath: int64
# HalfBath: int64
# BedroomAbvGr: int64
# KitchenAbvGr: int64
# TotRmsAbvGrd: int64
# Fireplaces: int64
# GarageYrBlt: float64
# GarageCars: int64
# GarageArea: int64
# WoodDeckSF: int64
# OpenPorchSF: int64
# EnclosedPorch: int64
# 3SsnPorch: int64
# ScreenPorch: int64
# PoolArea: int64
# MiscVal: int64
# MoSold: int64
# YrSold: int64

# %% [markdown]
# ## Make New Column with combinations

# %%
data4["SqFtPerRoom"] = data4["GrLivArea"] / (data4["TotRmsAbvGrd"] +
                                             data4["FullBath"] +
                                             data4["HalfBath"] +
                                             data4["KitchenAbvGr"])

data4['Total_Home_Quality'] = data4['OverallQual'] + data4['OverallCond']

data4['Total_Bathrooms'] = (data4['FullBath'] + (0.5 * data4['HalfBath']) +
                            data4['BsmtFullBath'] + (0.5 * data4['BsmtHalfBath']))

data4["HighQualSF"] = data4["1stFlrSF"] + data4["2ndFlrSF"]

# %%
data5 = data4.copy()

# %% [markdown]
# # Feature Transformations

# %% [markdown]
# ## Normalization for Skewed Features

# %%
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature'])
skew_df['Skew'] = skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew'].apply(lambda x: True if x >= 0.5 else False)
skew_df
# Out:
#                Feature       Skew  Absolute Skew  Skewed
# 0          LotFrontage   1.645574       1.645574    True
# 1              LotArea  12.822431      12.822431    True
# 2          OverallQual   0.197110       0.197110   False
# 3          OverallCond   0.570312       0.570312    True
# 4            YearBuilt  -0.599806       0.599806    True
# 5         YearRemodAdd  -0.451020       0.451020   False
# 6           MasVnrArea   2.611549       2.611549    True
# 7           BsmtFinSF1   1.425233       1.425233    True
# 8           BsmtFinSF2   4.146034       4.146034    True
# 9            BsmtUnfSF   0.919508       0.919508    True
# 10         TotalBsmtSF   1.162484       1.162484    True
# 11            1stFlrSF   1.469604       1.469604    True
# 12            2ndFlrSF   0.861675       0.861675    True
# 13        LowQualFinSF  12.088761      12.088761    True
# 14           GrLivArea   1.269358       1.269358    True
# ...

# %%
for column in skew_df.query("Skewed == True")['Feature'].values:
    data5[column] = np.log1p(data5[column])

# %% [markdown]
# Comparisons

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.title("Distribution before Transformation", fontsize=15)
sns.histplot(data4['LotArea'], kde=True, color="red")
plt.subplot(1,2,2)

plt.title("Distribution after Transformation", fontsize=15)
sns.histplot(np.log1p(data5['LotArea']),bins=20, kde=True , legend=False)
plt.xlabel('LotArea')
plt.show()

# %%
data6 = data5.copy()

# %% [markdown]
# # Encode Categoricals

# %% [markdown]
# ## OneHotEncoder

# %%
data6 = pd.get_dummies(data6)

# %%
data7 = data6.copy()

# %% [markdown]
# # Scaling

# %% [markdown]
# ## StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(data7)

data7 = pd.DataFrame(scaler.transform(data7), index=data7.index, columns=data7.columns)

# %% [markdown]
# ## Comparison

# %%
fig , (ob1, ob2) = plt.subplots(ncols = 2, figsize=(8,8))
ob1.set_title('Before Scaling')
sns.kdeplot(data6['HighQualSF'],ax=ob1)
sns.kdeplot(data6['MSZoning_RL'],ax=ob1)

ob2.set_title('After Standard Scaler')
sns.kdeplot(data7['HighQualSF'],ax=ob2)
sns.kdeplot(data7['MSZoning_RL'],ax=ob2)

plt.show()

# %%
data8 = data7.copy()

# %% [markdown]
# Target Transform

# %%
fig, axes = plt.subplots(1,2, figsize=(13, 5), sharey=False)
fig.suptitle('Distribution after Adjusting the SalePrice', size=25)
sns.histplot(target, ax=axes[0], kde=True)
sns.histplot(np.log(target), ax=axes[1], kde=True)
print('We can now observe normal distribution')
# Out:
# We can now observe normal distribution

# %%
log_target = np.log(target)

# %% [markdown]
# # Split Data

# %%
train_final = data8.loc[:data.index.max(), :].copy()
test_final = data8.loc[data.index.max() + 1:, :].reset_index(drop=True).copy()

# %%
train_final
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       -0.049717 -0.103719     0.646183    -0.435439   1.040634
# 1        0.588360  0.146544    -0.063185     1.906370   0.161526
# 2        0.088781  0.457629     0.646183    -0.435439   0.975922
# 3       -0.295173  0.136301     0.646183    -0.435439  -1.869638
# 4        0.738543  0.922662     1.355551    -0.435439   0.943542
# ...           ...       ...          ...          ...        ...
# 1455    -0.194659 -0.231508    -0.063185    -0.435439   0.911146
# 1456     0.774984  0.767440    -0.063185     0.454875   0.227056
# 1457    -0.002863  0.029092     0.646183     2.514892  -0.996100
# 1458     0.088781  0.170303    -0.772552     0.454875  -0.696444
# 1459     0.389841  0.214215    -0.772552     0.454875  -0.200076
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         0.896833    1.207310    0.783085   -0.363104  -0.326929
# ...

# %%
test_final
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        0.588360  0.521437    -0.772552     0.454875  -0.332070
# 1        0.626590  0.923625    -0.063185     0.454875  -0.431241
# 2        0.348573  0.862607    -0.772552    -0.435439   0.846305
# 3        0.510463  0.222291    -0.063185     0.454875   0.878733
# 4       -1.313021 -1.130892     1.355551    -0.435439   0.683917
# ...           ...       ...          ...          ...        ...
# 1454    -3.472654 -2.993401    -1.481920     1.226101  -0.035461
# 1455    -3.472654 -3.036401    -1.481920    -0.435439  -0.035461
# 1456     2.728701  1.586172    -0.772552     1.226101  -0.365110
# 1457    -0.194659  0.311255    -0.772552    -0.435439   0.683917
# 1458     0.348573  0.152052     0.646183    -0.435439   0.716427
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0        -1.113625   -0.806456    0.645381    2.285328  -0.013540
# ...

# %% [markdown]
# # Models

# %% [markdown]
# ## CatBoostRegression

# %%
catboost_params = {
    'iterations': 6000,
    'learning_rate': 0.005,
    'depth': 4,
    'l2_leaf_reg': 1,
    'eval_metric':'RMSE',
    'early_stopping_rounds': 200,
    'random_seed': 42
}

# %%
catBR = CatBoostRegressor(**catboost_params, verbose=0)

# %%
catBR.fit(train_final, log_target)

# %% [markdown]
# ## NeighborsRegressor

# %%
knn = KNeighborsRegressor()
knn.fit(train_final, log_target)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# # Evaluate

# %%
results = {}

kf = KFold(n_splits=10)

catBR_result = np.exp(np.sqrt(-cross_val_score(catBR, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))
knn_result = np.exp(np.sqrt(-cross_val_score(knn, train_final, log_target, scoring='neg_mean_squared_error', cv=kf)))

results[0] = catBR_result
results[1] = knn_result

# %%
print("-"*30)
print('CatBoost')
print(np.mean(results[0]))
print(np.std(results[0]))
print("-"*30)
print('KNN')
print(np.mean(results[1]))
print(np.std(results[1]))
# Out:
# ------------------------------
# CatBoost
# 1.122939865699395
# 0.020329805998677286
# ------------------------------
# KNN
# 1.213242711760985
# 0.026667014094370195

# %% [markdown]
# # Predictions

# %%
final_knn_prediction = np.exp(knn.predict(test_final))

# %%
final_cat_prediction = np.exp(catBR.predict(test_final))

# %% [markdown]
# # Submission

# %%
submission_CATBR = pd.concat([test_ids, pd.Series(final_cat_prediction, name='SalePrice')], axis=1)

# %%
submission_KNN = pd.concat([test_ids, pd.Series(final_knn_prediction, name='SalePrice')], axis=1)

# %%
submission_CATBR.to_csv('./submissions/submission4_1010.csv', index=False, header=True)

# %%
submission_KNN.to_csv('./submissions/submission5_1010.csv', index=False, header=True)
